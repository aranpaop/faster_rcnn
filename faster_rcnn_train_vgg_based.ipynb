# %%
from faster_rcnn import config
from faster_rcnn import vgg
from faster_rcnn import parser
from faster_rcnn import data_generators
from faster_rcnn import losses
from faster_rcnn import roi_helpers

import pickle
import time
import numpy as np
from imp import reload

from keras.utils import generic_utils
from keras.optimizers import Adam
from keras.layers import Input
from keras.models import Model

# %%
# 用于修改模块后重新加载
reload(config)
reload(vgg)
reload(parser)
reload(data_generators)
reload(losses)
reload(roi_helpers)
# Out:
# <module 'faster_rcnn.roi_helpers' from 'C:\\Users\\paops\\Desktop\\sqdt\\vehicledetector\\faster_rcnn\\roi_helpers.py'>

# %%
C = config.Config() # 参数
# 在训练时进行数据增广
C.use_horizontal_flips = True
C.use_vertical_flips = True
C.rot_90 = True

img_path = 'data_object_image_2/training/image_2' # 训练图片路径
label_path = 'data_object_label_2/training/label_2' # 训练标签路径

all_imgs, classes_count, class_mapping = parser.get_data(img_path, label_path)
C.class_mapping = class_mapping

# 保存训练参数
with open(C.config_filename, 'wb') as config_f:
    pickle.dump(C, config_f)

train_imgs = [s for s in all_imgs if s['imageset'] == 'trainval']
val_imgs = [s for s in all_imgs if s['imageset'] == 'test']

print('Num train samples {}'.format(len(train_imgs)))
print('Num val samples {}'.format(len(val_imgs)))

# 产生训练与验证数据
data_gen_train = data_generators.get_anchor_gt(train_imgs, classes_count, img_path, C, mode = 'train')
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, img_path, C, mode = 'val')
# Out:
# Num train samples 824
# Num val samples 176

# %%
classes_count
# Out:
# {'people': 865, 'vehicle': 4334, 'bg': 0}

# %%
class_mapping
# Out:
# {'people': 0, 'vehicle': 1, 'bg': 2}

# %%
all_imgs[0]
# Out:
# {'filepath': '000018.png',
#  'width': 1242,
#  'height': 375,
#  'bboxes': [{'class': 'vehicle', 'x1': 523, 'x2': 550, 'y1': 194, 'y2': 219},
#   {'class': 'vehicle', 'x1': 572, 'x2': 606, 'y1': 185, 'y2': 219},
#   {'class': 'vehicle', 'x1': 387, 'x2': 473, 'y1': 166, 'y2': 213}],
#  'imageset': 'trainval'}

# %%
# 定义输入维度
img_input = Input(shape = (None, None, 3))
roi_input = Input(shape = (None, 4))

# 定义共享层
shared_layers = vgg.nn_base(img_input, trainable = False)

# 定义共享层基础上的rpn层
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn = vgg.rpn(shared_layers, num_anchors)

# 定义共享层及rpn层基础上的分类层
classifier = vgg.classifier(shared_layers, roi_input, C.num_rois, nb_classes = len(classes_count), trainable = True)

model_rpn = Model(img_input, rpn[:2])
model_classifier = Model([img_input, roi_input], classifier)
model_all = Model([img_input, roi_input], rpn[:2] + classifier) # 该模型只用于保存训练权重

# 依据层名载入预训练参数
model_rpn.load_weights(C.base_net_weights, by_name = True)
model_classifier.load_weights(C.base_net_weights, by_name = True)

# 模型编译
optimizer = Adam(lr = 1e-3)
optimizer_classifier = Adam(lr = 1e-3)
model_rpn.compile(optimizer = optimizer, loss = [losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer = optimizer_classifier, loss = [losses.class_loss_cls, losses.class_loss_regr(len(classes_count) - 1)], metrics={'dense_class_{}'.format(len(classes_count)): 'accuracy'})
model_all.compile(optimizer = 'sgd', loss = 'mae')

# %%
# 设置每个epoch长度，以及epoch数
epoch_length = 500
num_epochs = 10
iter_num = 0

losses = np.zeros((epoch_length, 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []
start_time = time.time()
best_loss = np.Inf

print('Starting training')

for epoch_num in range(num_epochs):
    progbar = generic_utils.Progbar(epoch_length)
    print('Epoch {}/{}'.format(epoch_num + 1, num_epochs))
    while 1:
        try:
            # 每到epoch长度的迭代数时输出与bounding box重合的平均数
            if len(rpn_accuracy_rpn_monitor) == epoch_length:
                mean_overlapping_bboxes = sum(rpn_accuracy_rpn_monitor) / len(rpn_accuracy_rpn_monitor)
                rpn_accuracy_rpn_monitor = []
                print('Average number of overlapping bounding boxes from RPN = {} for {} previous iterations'.format(mean_overlapping_bboxes, epoch_length))
                if mean_overlapping_bboxes == 0:
                    print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')
            # 产生训练特征，训练标签，与图像数据
            X, Y, img_data = next(data_gen_train)
            # 训练rpn网络
            loss_rpn = model_rpn.train_on_batch(X, Y)
            # 利用训练的rpn网络进行预测
            P_rpn = model_rpn.predict_on_batch(X)
            # 计算用于分类的bounding boxes、类别独热码、与应类别标签及坐标
            R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, use_regr = True, overlap_thresh = 0.7, max_boxes = 300)
            X2, Y1, Y2 = roi_helpers.calc_iou(R, img_data, C, class_mapping)
            
            if X2 is None:
                rpn_accuracy_rpn_monitor.append(0)
                rpn_accuracy_for_epoch.append(0)
                continue
            
            # 背景为1的样本为neg样本，背景为0的样本为pos样本
            neg_samples = np.where(Y1[0, :, -1] == 1)
            pos_samples = np.where(Y1[0, :, -1] == 0)
            
            if len(neg_samples) > 0:
                neg_samples = neg_samples[0]
            else:
                neg_samples = []

            if len(pos_samples) > 0:
                pos_samples = pos_samples[0]
            else:
                pos_samples = []

            rpn_accuracy_rpn_monitor.append(len(pos_samples))
            rpn_accuracy_for_epoch.append((len(pos_samples)))
            
            # 若pos样本数量小于num_rois的一半，则选取所有的pos样本，否则，选取num_rois一半数量的pos样本，剩下的样本使用neg样本
            if C.num_rois > 1:
                if len(pos_samples) < C.num_rois // 2:
                    selected_pos_samples = pos_samples.tolist()
                else:
                    selected_pos_samples = np.random.choice(pos_samples, C.num_rois // 2, replace = False).tolist()
                try:
                    selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace = False).tolist()
                except:
                    selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace = True).tolist()

                sel_samples = selected_pos_samples + selected_neg_samples
            
            # 若num_rois为1时，随机选取pos或neg样本
            else:
                selected_pos_samples = pos_samples.tolist()
                selected_neg_samples = neg_samples.tolist()
                if np.random.randint(0, 2):
                    sel_samples = random.choice(neg_samples)
                else:
                    sel_samples = random.choice(pos_samples)

            # 训练分类模型
            loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

            losses[iter_num, 0] = loss_rpn[1] # rpn分类损失
            losses[iter_num, 1] = loss_rpn[2] # rpn回归损失

            losses[iter_num, 2] = loss_class[1] # classifier分类损失
            losses[iter_num, 3] = loss_class[2] # classifier回归损失
            losses[iter_num, 4] = loss_class[3] # classifier分类准确率

            iter_num += 1
            
            # 实时反馈模型损失
            progbar.update(iter_num, [('rpn_cls', np.mean(losses[:iter_num, 0])), ('rpn_regr', np.mean(losses[:iter_num, 1])),
                                      ('detector_cls', np.mean(losses[:iter_num, 2])), ('detector_regr', np.mean(losses[:iter_num, 3]))])
            
            if iter_num == epoch_length:
                loss_rpn_cls = np.mean(losses[:, 0])
                loss_rpn_regr = np.mean(losses[:, 1])
                loss_class_cls = np.mean(losses[:, 2])
                loss_class_regr = np.mean(losses[:, 3])
                class_acc = np.mean(losses[:, 4])

                mean_overlapping_bboxes = sum(rpn_accuracy_for_epoch) / len(rpn_accuracy_for_epoch)
                rpn_accuracy_for_epoch = []

                print('Mean number of bounding boxes from RPN overlapping ground truth boxes: {}'.format(mean_overlapping_bboxes))
                print('Classifier accuracy for bounding boxes from RPN: {}'.format(class_acc))
                print('Loss RPN classifier: {}'.format(loss_rpn_cls))
                print('Loss RPN regression: {}'.format(loss_rpn_regr))
                print('Loss Detector classifier: {}'.format(loss_class_cls))
                print('Loss Detector regression: {}'.format(loss_class_regr))
                print('Elapsed time: {}'.format(time.time() - start_time))

                curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
                iter_num = 0
                start_time = time.time()

                # 当前损失小于最佳损失时，保存当前损失与模型参数
                if curr_loss < best_loss:
                    print('Total loss decreased from {} to {}, saving weights'.format(best_loss,curr_loss))
                    best_loss = curr_loss
                    model_all.save_weights(C.model_path)

                break

        except Exception as e:
            print('Exception: {}'.format(e))
            continue

print('Training complete, exiting.')
# Out:
# Starting training
# Epoch 1/10
#  68/500 [===>..........................] - ETA: 1:09:53 - rpn_cls: 5.6750 - rpn_regr: 1.4677 - detector_cls: 1.8835 - detector_regr: 3.1579Exception: too many values to unpack (expected 3)
#  91/500 [====>.........................] - ETA: 1:06:59 - rpn_cls: 5.4816 - rpn_regr: 1.4706 - detector_cls: 2.0485 - detector_regr: 3.3409Exception: too many values to unpack (expected 3)
# 178/500 [=========>....................] - ETA: 53:09 - rpn_cls: 5.1341 - rpn_regr: 1.4495 - detector_cls: 2.4279 - detector_regr: 3.4910Exception: too many values to unpack (expected 3)
# 182/500 [=========>....................] - ETA: 52:41 - rpn_cls: 5.1220 - rpn_regr: 1.4487 - detector_cls: 2.4378 - detector_regr: 3.4944Exception: too many values to unpack (expected 3)
# 212/500 [===========>..................] - ETA: 47:50 - rpn_cls: 5.0364 - rpn_regr: 1.4429 - detector_cls: 2.5056 - detector_regr: 3.4955Exception: too many values to unpack (expected 3)
# 433/500 [========================>.....] - ETA: 11:14 - rpn_cls: 4.6124 - rpn_regr: 1.3906 - detector_cls: 2.6422 - detector_regr: 3.1249Exception: too many values to unpack (expected 3)
# 484/500 [============================>.] - ETA: 2:42 - rpn_cls: 4.5385 - rpn_regr: 1.3800 - detector_cls: 2.6327 - detector_regr: 3.0399Exception: too many values to unpack (expected 3)
# 500/500 [==============================] - 5089s 10s/step - rpn_cls: 4.5171 - rpn_regr: 1.3767 - detector_cls: 2.6282 - detector_regr: 3.0142
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.828
# Classifier accuracy for bounding boxes from RPN: 0.71175
# Loss RPN classifier: 3.8614743045460402
# Loss RPN regression: 1.2697716426253318
# Loss Detector classifier: 2.472912635830823
# Loss Detector regression: 2.21471747019887
# Elapsed time: 5088.822981595993
# Total loss decreased from inf to 9.818876053201066, saving weights
# Epoch 2/10
# Average number of overlapping bounding boxes from RPN = 2.828 for 500 previous iterations
#  87/500 [====>.........................] - ETA: 1:16:51 - rpn_cls: 3.1132 - rpn_regr: 1.2445 - detector_cls: 1.4723 - detector_regr: 1.1829Exception: too many values to unpack (expected 3)
# 118/500 [======>.......................] - ETA: 1:12:37 - rpn_cls: 3.1443 - rpn_regr: 1.2074 - detector_cls: 1.4976 - detector_regr: 1.1343Exception: too many values to unpack (expected 3)
# 329/500 [==================>...........] - ETA: 30:58 - rpn_cls: 3.0918 - rpn_regr: 1.1294 - detector_cls: 1.4774 - detector_regr: 1.0213Exception: too many values to unpack (expected 3)
# 352/500 [====================>.........] - ETA: 26:42 - rpn_cls: 3.0854 - rpn_regr: 1.1268 - detector_cls: 1.4731 - detector_regr: 1.0176Exception: too many values to unpack (expected 3)
# 400/500 [=======================>......] - ETA: 17:57 - rpn_cls: 3.0730 - rpn_regr: 1.1229 - detector_cls: 1.4649 - detector_regr: 1.0173Exception: too many values to unpack (expected 3)
# 460/500 [==========================>...] - ETA: 7:08 - rpn_cls: 3.0630 - rpn_regr: 1.1188 - detector_cls: 1.4558 - detector_regr: 1.0208Exception: too many values to unpack (expected 3)
# 500/500 [==============================] - 5334s 11s/step - rpn_cls: 3.0578 - rpn_regr: 1.1157 - detector_cls: 1.4495 - detector_regr: 1.0205
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.222
# Classifier accuracy for bounding boxes from RPN: 0.6455
# Loss RPN classifier: 3.0095149977416504
# Loss RPN regression: 1.0751704954952002
# Loss Detector classifier: 1.3657052795063958
# Loss Detector regression: 0.9982461333146785
# Elapsed time: 5335.557059288025
# Total loss decreased from 9.818876053201066 to 6.448636906057925, saving weights
# Epoch 3/10
# Average number of overlapping bounding boxes from RPN = 4.222 for 500 previous iterations
#  88/500 [====>.........................] - ETA: 1:08:51 - rpn_cls: 2.9635 - rpn_regr: 0.9752 - detector_cls: 1.4165 - detector_regr: 0.8257Exception: too many values to unpack (expected 3)
# 178/500 [=========>....................] - ETA: 54:20 - rpn_cls: 2.9335 - rpn_regr: 0.9928 - detector_cls: 1.3940 - detector_regr: 0.9709Exception: too many values to unpack (expected 3)
# 479/500 [===========================>..] - ETA: 3:38 - rpn_cls: 2.8134 - rpn_regr: 1.0170 - detector_cls: 1.2951 - detector_regr: 0.9615Exception: too many values to unpack (expected 3)
# 500/500 [==============================] - 5209s 10s/step - rpn_cls: 2.8075 - rpn_regr: 1.0183 - detector_cls: 1.2892 - detector_regr: 0.9579
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.0
# Classifier accuracy for bounding boxes from RPN: 0.6515
# Loss RPN classifier: 2.6711134222205115
# Loss RPN regression: 1.0487089579701423
# Loss Detector classifier: 1.1529527977130456
# Loss Detector regression: 0.8700415729675443
# Elapsed time: 5209.6185619831085
# Total loss decreased from 6.448636906057925 to 5.742816750871244, saving weights
# Epoch 4/10
# Average number of overlapping bounding boxes from RPN = 5.0 for 500 previous iterations
#  15/500 [..............................] - ETA: 1:22:55 - rpn_cls: 2.6610 - rpn_regr: 1.1595 - detector_cls: 0.8718 - detector_regr: 0.7556Exception: too many values to unpack (expected 3)
# 282/500 [===============>..............] - ETA: 43:27 - rpn_cls: 2.4261 - rpn_regr: 0.9618 - detector_cls: 1.0165 - detector_regr: 0.7036Exception: too many values to unpack (expected 3)
# 498/500 [============================>.] - ETA: 25s - rpn_cls: 2.4299 - rpn_regr: 0.9579 - detector_cls: 1.0600 - detector_regr: 0.7105Exception: too many values to unpack (expected 3)
# 500/500 [==============================] - 6328s 13s/step - rpn_cls: 2.4302 - rpn_regr: 0.9579 - detector_cls: 1.0601 - detector_regr: 0.7106
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.202
# Classifier accuracy for bounding boxes from RPN: 0.651
# Loss RPN classifier: 2.498975491465235
# Loss RPN regression: 0.9630890332907438
# Loss Detector classifier: 1.0911781761927395
# Loss Detector regression: 0.7238967575952411
# Elapsed time: 6328.493137121201
# Total loss decreased from 5.742816750871244 to 5.27713945854396, saving weights
# Epoch 5/10
# Average number of overlapping bounding boxes from RPN = 5.202 for 500 previous iterations
#  10/500 [..............................] - ETA: 1:53:27 - rpn_cls: 2.5915 - rpn_regr: 0.7335 - detector_cls: 0.6570 - detector_regr: 0.5474Exception: too many values to unpack (expected 3)
#  66/500 [==>...........................] - ETA: 1:33:02 - rpn_cls: 2.4214 - rpn_regr: 0.7779 - detector_cls: 0.8329 - detector_regr: 0.4824Exception: too many values to unpack (expected 3)
# 240/500 [=============>................] - ETA: 48:35 - rpn_cls: 2.2348 - rpn_regr: 0.8151 - detector_cls: 0.9088 - detector_regr: 0.5580Exception: too many values to unpack (expected 3)
# 331/500 [==================>...........] - ETA: 30:53 - rpn_cls: 2.2484 - rpn_regr: 0.8276 - detector_cls: 0.9318 - detector_regr: 0.5734Exception: too many values to unpack (expected 3)
# 342/500 [===================>..........] - ETA: 28:51 - rpn_cls: 2.2530 - rpn_regr: 0.8288 - detector_cls: 0.9340 - detector_regr: 0.5747Exception: too many values to unpack (expected 3)
# 500/500 [==============================] - 5350s 11s/step - rpn_cls: 2.2917 - rpn_regr: 0.8382 - detector_cls: 0.9564 - detector_regr: 0.5885
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.936
# Classifier accuracy for bounding boxes from RPN: 0.6425
# Loss RPN classifier: 2.389699879658795
# Loss RPN regression: 0.860149085663259
# Loss Detector classifier: 1.0099383501540868
# Loss Detector regression: 0.6235625475428532
# Elapsed time: 5350.346774816513
# Total loss decreased from 5.27713945854396 to 4.883349863018994, saving weights
# Epoch 6/10
# Average number of overlapping bounding boxes from RPN = 5.936 for 500 previous iterations
# 193/500 [==========>...................] - ETA: 53:07 - rpn_cls: 2.4278 - rpn_regr: 0.7991 - detector_cls: 1.1404 - detector_regr: 0.6172Exception: too many values to unpack (expected 3)
# 273/500 [===============>..............] - ETA: 39:50 - rpn_cls: 2.4533 - rpn_regr: 0.8068 - detector_cls: 1.1116 - detector_regr: 0.6231Exception: too many values to unpack (expected 3)
# 353/500 [====================>.........] - ETA: 25:57 - rpn_cls: 2.4698 - rpn_regr: 0.8151 - detector_cls: 1.0957 - detector_regr: 0.6349Exception: too many values to unpack (expected 3)
# 370/500 [=====================>........] - ETA: 23:03 - rpn_cls: 2.4739 - rpn_regr: 0.8165 - detector_cls: 1.0925 - detector_regr: 0.6374Exception: too many values to unpack (expected 3)
# 390/500 [======================>.......] - ETA: 19:34 - rpn_cls: 2.4771 - rpn_regr: 0.8180 - detector_cls: 1.0886 - detector_regr: 0.6410Exception: too many values to unpack (expected 3)
# 500/500 [==============================] - 5399s 11s/step - rpn_cls: 2.4747 - rpn_regr: 0.8261 - detector_cls: 1.0699 - detector_regr: 0.6482
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 6.336
# Classifier accuracy for bounding boxes from RPN: 0.63525
# Loss RPN classifier: 2.4029188658948217
# Loss RPN regression: 0.8635954606160522
# Loss Detector classifier: 1.0052364053279204
# Loss Detector regression: 0.6605391546960454
# Elapsed time: 5399.715440750122
# Epoch 7/10
# Average number of overlapping bounding boxes from RPN = 6.336 for 500 previous iterations
# 126/500 [======>.......................] - ETA: 1:24:18 - rpn_cls: 2.2363 - rpn_regr: 0.8891 - detector_cls: 0.9371 - detector_regr: 0.5954Exception: too many values to unpack (expected 3)
# 176/500 [=========>....................] - ETA: 1:13:22 - rpn_cls: 2.2220 - rpn_regr: 0.8774 - detector_cls: 0.9557 - detector_regr: 0.6214Exception: a must be non-empty
# 312/500 [=================>............] - ETA: 42:27 - rpn_cls: 2.2385 - rpn_regr: 0.8683 - detector_cls: 0.9679 - detector_regr: 0.6415Exception: too many values to unpack (expected 3)
# 412/500 [=======================>......] - ETA: 19:49 - rpn_cls: 2.2653 - rpn_regr: 0.8626 - detector_cls: 0.9668 - detector_regr: 0.6341Exception: too many values to unpack (expected 3)
# 479/500 [===========================>..] - ETA: 4:44 - rpn_cls: 2.2777 - rpn_regr: 0.8593 - detector_cls: 0.9640 - detector_regr: 0.6281Exception: too many values to unpack (expected 3)
# 499/500 [============================>.] - ETA: 13s - rpn_cls: 2.2802 - rpn_regr: 0.8585 - detector_cls: 0.9632 - detector_regr: 0.6263Average number of overlapping bounding boxes from RPN = 6.594 for 500 previous iterations
# 500/500 [==============================] - 6766s 14s/step - rpn_cls: 2.2803 - rpn_regr: 0.8585 - detector_cls: 0.9632 - detector_regr: 0.6263
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 6.592814371257485
# Classifier accuracy for bounding boxes from RPN: 0.631
# Loss RPN classifier: 2.336850017644733
# Loss RPN regression: 0.8406688844002783
# Loss Detector classifier: 0.9418102574720979
# Loss Detector regression: 0.5808014704324305
# Elapsed time: 6766.0538828372955
# Total loss decreased from 4.883349863018994 to 4.700130629949539, saving weights
# Epoch 8/10
# 176/500 [=========>....................] - ETA: 1:12:26 - rpn_cls: 2.1109 - rpn_regr: 0.7907 - detector_cls: 0.9211 - detector_regr: 0.5286Exception: a must be non-empty
# 350/500 [====================>.........] - ETA: 33:39 - rpn_cls: 2.1981 - rpn_regr: 0.7944 - detector_cls: 0.9373 - detector_regr: 0.5698Exception: too many values to unpack (expected 3)
# 388/500 [======================>.......] - ETA: 25:09 - rpn_cls: 2.2181 - rpn_regr: 0.7968 - detector_cls: 0.9428 - detector_regr: 0.5730Exception: too many values to unpack (expected 3)
# 498/500 [============================>.] - ETA: 26s - rpn_cls: 2.2609 - rpn_regr: 0.8041 - detector_cls: 0.9483 - detector_regr: 0.5725Average number of overlapping bounding boxes from RPN = 5.998 for 500 previous iterations
# 500/500 [==============================] - 6499s 13s/step - rpn_cls: 2.2613 - rpn_regr: 0.8042 - detector_cls: 0.9483 - detector_regr: 0.5724
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.982035928143713
# Classifier accuracy for bounding boxes from RPN: 0.64175
# Loss RPN classifier: 2.3730402515917772
# Loss RPN regression: 0.8249201007187367
# Loss Detector classifier: 0.9641471725963127
# Loss Detector regression: 0.5531789932656102
# Elapsed time: 6499.575098276138
# Epoch 9/10
# 152/500 [========>.....................] - ETA: 59:59 - rpn_cls: 2.2592 - rpn_regr: 0.7382 - detector_cls: 0.8445 - detector_regr: 0.5119  Exception: too many values to unpack (expected 3)
# 200/500 [===========>..................] - ETA: 51:59 - rpn_cls: 2.2444 - rpn_regr: 0.7516 - detector_cls: 0.8719 - detector_regr: 0.5470Exception: too many values to unpack (expected 3)
# 498/500 [============================>.] - ETA: 21s - rpn_cls: 2.1704 - rpn_regr: 0.7930 - detector_cls: 0.8987 - detector_regr: 0.5814Average number of overlapping bounding boxes from RPN = 7.182 for 500 previous iterations
# 500/500 [==============================] - 5359s 11s/step - rpn_cls: 2.1702 - rpn_regr: 0.7932 - detector_cls: 0.8986 - detector_regr: 0.5815
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.192
# Classifier accuracy for bounding boxes from RPN: 0.632
# Loss RPN classifier: 2.1288377285701965
# Loss RPN regression: 0.8292819855567067
# Loss Detector classifier: 0.888965334784647
# Loss Detector regression: 0.5859763022055849
# Elapsed time: 5358.999644756317
# Total loss decreased from 4.700130629949539 to 4.433061351117135, saving weights
# Epoch 10/10
#  27/500 [>.............................] - ETA: 1:28:40 - rpn_cls: 2.7154 - rpn_regr: 0.8987 - detector_cls: 0.7392 - detector_regr: 0.6004Exception: a must be non-empty
# 229/500 [============>.................] - ETA: 47:08 - rpn_cls: 2.6555 - rpn_regr: 0.8371 - detector_cls: 0.9992 - detector_regr: 0.8192Exception: too many values to unpack (expected 3)
# 235/500 [=============>................] - ETA: 46:13 - rpn_cls: 2.6502 - rpn_regr: 0.8366 - detector_cls: 0.9982 - detector_regr: 0.8152Exception: too many values to unpack (expected 3)
# 295/500 [================>.............] - ETA: 35:41 - rpn_cls: 2.5937 - rpn_regr: 0.8321 - detector_cls: 0.9856 - detector_regr: 0.7790Exception: too many values to unpack (expected 3)
# 497/500 [============================>.] - ETA: 31s - rpn_cls: 2.4754 - rpn_regr: 0.8222 - detector_cls: 0.9794 - detector_regr: 0.7603Average number of overlapping bounding boxes from RPN = 6.248 for 500 previous iterations
# 500/500 [==============================] - 5179s 10s/step - rpn_cls: 2.4742 - rpn_regr: 0.8221 - detector_cls: 0.9794 - detector_regr: 0.7602
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 6.2375249500998
# Classifier accuracy for bounding boxes from RPN: 0.6455
# Loss RPN classifier: 2.2823697649695416
# Loss RPN regression: 0.8056960793212056
# Loss Detector classifier: 0.9721058830469846
# Loss Detector regression: 0.7433336317827925
# Elapsed time: 5179.786992549896
# Training complete, exiting.
